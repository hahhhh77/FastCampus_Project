# %% [markdown]
# # **Retail 데이터를 활용한 데이터 전처리 연습**
#
# - 실습 데이터 출처 : [Kaggle-Retail Case Study Data](https://www.kaggle.com/datasets/darpan25bajaj/retail-case-study-data)

# %% [markdown]
# ## **실습 데이터 설명**

# %% [markdown]
# * **<font color = 'brown'>Customer 데이터 명세</font> : 고객의 인적 정보를 담고 있는 데이터 (고객id, 생년월일, 성별, 거주지 코드)**
#
# |컬럼명|의미|구성요소 상세|
# |:---|:---|:---|
# |customer_id|고객id|고객 식별 값|
# |DOB|고객 생년월일|날짜 형식 데이터|
# |Gender|고객 성별|M:남성 / F:여성|
# |city_code|거주지 코드|1~10까지 숫자로 구성|
#
# <br>
#
# * **<font color = 'brown'>Transactions 데이터 명세</font>: 거래 내역 데이터 (고객id, 주문id, 거래 일자, 카테고리 콛, 거래 금액 등)**
#
# |컬럼명|의미|구성요소 상세|
# |:---|:---|:---|
# |transaction_id|거래 id|거래 발생 시 부여되는 번호|
# |cust_id|고객 id|Customer의 customer_id와 동일|
# |tran_date|거래 일자|날짜 형식 데이터|
# |prod_sub_cat_code|서브 카테고리 코드|숫자 형식 데이터|
# |prod_cat_code|대 카테고리 코드|숫자 형식 데이터|
# |Qty|주문 수량|음수로 기록된 데이터도 존재|
# |Rate|판매 금액|음수로 기록된 데이터도 존재|
# |Tax|세금|음수로 기록된 데이터에도 양수로 기록된|
# |total_amt|거래 금액|판매금액 X 주문 수량 + 세금|
# |Store_type|거래가 발생한 판매 채널 타입|e-shop, TeleShop, Flagship store, MBR|
#
# <br>
#
# * **<font color = 'brown'>prod_cat_info 데이터 명세</font>: 카테고리 코드/명칭 데이터(대 카테고리 코드/명칭, 서브 카테고리 코드/명칭)**
#
#
# |컬럼명|의미|구성요소 상세|
# |:---|:---|:---|
# |prod_cat_code|대 카테고리 코드|Transactions 데이터에도 존재|
# |prod_cat|대 카테고리 명칭|상세 명칭|
# |prod_sub_cat_code|서브 카테고리 코드|Transactions 데이터에도 존재|
# |prod_subcat|서브 카테고리 명칭|상세 명칭|

# %% [markdown]
# ## **데이터 불러오기**

# %%
# 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# pandas 라이브러리 불러오기
import pandas as pd

# %%
# 필요한 데이터 불러오기
# Customer
customer = pd.read_csv('/content/drive/MyDrive/DataDreamworks/패스트캠퍼스/커머스/class01/data/Customer.csv')
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_Id  5647 non-null   int64
#  1   DOB          5647 non-null   object
#  2   Gender       5645 non-null   object
#  3   city_code    5645 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 176.6+ KB

# %%
customer.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
# 필요한 데이터 불러오기
# Transactions
transactions = pd.read_csv('/content/drive/MyDrive/DataDreamworks/패스트캠퍼스/커머스/class01/data/Transactions.csv')
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23053 entries, 0 to 23052
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    23053 non-null  int64
#  1   cust_id           23053 non-null  int64
#  2   tran_date         23053 non-null  object
#  3   prod_subcat_code  23053 non-null  int64
#  4   prod_cat_code     23053 non-null  int64
#  5   Qty               23053 non-null  int64
#  6   Rate              23053 non-null  int64
#  7   Tax               23053 non-null  float64
#  8   total_amt         23053 non-null  float64
#  9   Store_type        23053 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.8+ MB

# %%
transactions.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
# 필요한 데이터 불러오기
# prod_cat_info
prod_cat_info = pd.read_csv('/content/drive/MyDrive/DataDreamworks/패스트캠퍼스/커머스/class01/data/prod_cat_info.csv')
prod_cat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   prod_cat_code      23 non-null     int64
#  1   prod_cat           23 non-null     object
#  2   prod_sub_cat_code  23 non-null     int64
#  3   prod_subcat        23 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 864.0+ bytes

# %%
prod_cat_info.head()
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %% [markdown]
# ## **결측치 데이터 확인 및 처리**

# %% [markdown]
# ### <font color = 'grey'>**Customer 데이터 결측치 확인 및 처리**</font>
# - Gender 컬럼의 결측치는 unknown 값으로 대체
# - city_code 컬럼의 결측치는 빈도수 높은 값으로 대체

# %%
# 각 컬럼별 결측치 수 확인
customer.isnull().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         2
# city_code      2
# dtype: int64

# %%
# 결측치 데이터 확인
## Gender 결측치
customer[customer["Gender"].isnull()]
# Out:
#     customer_Id         DOB Gender  city_code
# 24       267199  14-02-1970    NaN        2.0
# 87       271626  02-06-1970    NaN        6.0

# %%
## 결측치를 unknown으로 대체
customer["Gender"] = customer["Gender"].fillna("unknown")

## 성별 데이터 집계
customer.groupby("Gender").count()["customer_Id"]
# Out:
# Gender
# F          2753
# M          2892
# unknown       2
# Name: customer_Id, dtype: int64

# %%
# 결측치 데이터 확인
## city_code 결측치
customer[customer["city_code"].isnull()]
# Out:
#      customer_Id         DOB Gender  city_code
# 115       268447  14-07-1970      M        NaN
# 149       268709  09-09-1970      F        NaN

# %%
# city_code의 결측치는 데이터 중 가장 많은 값을 가지고 있는 코드로 임의 대체
## city_code 데이터 집계 (빈도수대로 내림차순 정렬하여 확인)
customer.groupby("city_code").count()["customer_Id"].sort_values(ascending=False)
# Out:
# city_code
# 3.0     595
# 5.0     586
# 4.0     582
# 7.0     575
# 2.0     564
# 8.0     562
# 10.0    558
# 1.0     551
# 9.0     546
# 6.0     526
# Name: customer_Id, dtype: int64

# %%
# city_code의 결측치를 city_code 최대값 지역인 3으로 임의 부여
customer["city_code"] = customer["city_code"].fillna(3)

# city_code 결측치 다시 확인
customer[customer["city_code"].isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_Id, DOB, Gender, city_code]
# Index: []

# %%
# 각 컬럼별 결측치 수 다시 확인
customer.isnull().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         0
# city_code      0
# dtype: int64

# %% [markdown]
# ## **날짜 데이터 전처리**

# %% [markdown]
# ### <font color = 'grey'>**Case 1. dd-mm-yyyy 형식을 yyyy-mm-dd 형식으로 변환**</font>
# - **'dd-mm-yyyy'**형식을 한국에서 많이 사용하는 날짜 표기 형태인 **'yyyy-mm-dd'** 형식으로 변환

# %%
# 날짜 데이터 확인
customer["DOB"].unique()
# Out:
# array(['02-01-1970', '07-01-1970', '08-01-1970', ..., '25-12-1992',
#        '27-12-1992', '29-12-1992'], dtype=object)

# %%
customer.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
# 날짜 포맷을 %d-%m-%Y 형식으로 지정하여 변환하기
customer["DOB"] = pd.to_datetime(customer["DOB"], format='%d-%m-%Y')
customer.head()
# Out:
#    customer_Id        DOB Gender  city_code
# 0       268408 1970-01-02      M        4.0
# 1       269696 1970-01-07      F        8.0
# 2       268159 1970-01-08      F        8.0
# 3       270181 1970-01-10      F        2.0
# 4       268073 1970-01-11      M        1.0

# %%
# customer의 데이터 타입 다시 확인
customer.dtypes
# Out:
# customer_Id             int64
# DOB            datetime64[ns]
# Gender                 object
# city_code             float64
# dtype: object

# %% [markdown]
# ### <font color = 'grey'>**Case 2. 문자형 타입 데이터를 yyyy-mm-dd 형식으로 변환**</font>

# %%
# transactions 데이터 구조 확인
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23053 entries, 0 to 23052
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    23053 non-null  int64
#  1   cust_id           23053 non-null  int64
#  2   tran_date         23053 non-null  object
#  3   prod_subcat_code  23053 non-null  int64
#  4   prod_cat_code     23053 non-null  int64
#  5   Qty               23053 non-null  int64
#  6   Rate              23053 non-null  int64
#  7   Tax               23053 non-null  float64
#  8   total_amt         23053 non-null  float64
#  9   Store_type        23053 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.8+ MB

# %%
# head 함수로 데이터 일부 확인
transactions.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
# 한 열에 공통되지 않은 데이터 형태 수정
# slash 패턴 데이터 확인
slash_pattern= transactions["tran_date"].str.contains("/")
transactions.loc[slash_pattern]
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 144       12323853707   273552  12/2/2014                12              6
# 145       60596009595   274652  12/2/2014                12              5
# 146       17146707816   274897  12/2/2014                12              5
# 147       36792372906   275246  12/2/2014                 2              6
# 148       38821078489   267025  12/2/2014                10              6
# ...               ...      ...        ...               ...            ...
# 22907     80348907828   267124   1/2/2011                 5              3
# 22908     83849473598   269958   1/2/2011                12              5
# 22909     95376486237   269403   1/2/2011                 4              3
# 22910     81365620177   274222   1/2/2011                 3              2
# 22911     85848725285   271131   1/2/2011                 1              4
#
#        Qty  Rate      Tax  total_amt Store_type
# 144      4   510  214.200   2254.200   TeleShop
# 145      4   183   76.860    808.860        MBR
# 146      3   622  195.930   2061.930        MBR
# 147      1  1185  124.425   1309.425     e-Shop
# 148      4   933  391.860   4123.860     e-Shop
# ...    ...   ...      ...        ...        ...
# 22907    2   552  115.920   1219.920   TeleShop
# 22908    3   403  126.945   1335.945     e-Shop
# 22909    5   673  353.325   3718.325        MBR
# 22910    3   373  117.495   1236.495     e-Shop
# 22911    5  1043  547.575   5762.575     e-Shop
#
# [9124 rows x 10 columns]

# %%
# '/'를 '-'로 변경
transactions["tran_date"] = transactions["tran_date"].str.replace("/", "-")
transactions.loc[slash_pattern]
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 144       12323853707   273552  12-2-2014                12              6
# 145       60596009595   274652  12-2-2014                12              5
# 146       17146707816   274897  12-2-2014                12              5
# 147       36792372906   275246  12-2-2014                 2              6
# 148       38821078489   267025  12-2-2014                10              6
# ...               ...      ...        ...               ...            ...
# 22907     80348907828   267124   1-2-2011                 5              3
# 22908     83849473598   269958   1-2-2011                12              5
# 22909     95376486237   269403   1-2-2011                 4              3
# 22910     81365620177   274222   1-2-2011                 3              2
# 22911     85848725285   271131   1-2-2011                 1              4
#
#        Qty  Rate      Tax  total_amt Store_type
# 144      4   510  214.200   2254.200   TeleShop
# 145      4   183   76.860    808.860        MBR
# 146      3   622  195.930   2061.930        MBR
# 147      1  1185  124.425   1309.425     e-Shop
# 148      4   933  391.860   4123.860     e-Shop
# ...    ...   ...      ...        ...        ...
# 22907    2   552  115.920   1219.920   TeleShop
# 22908    3   403  126.945   1335.945     e-Shop
# 22909    5   673  353.325   3718.325        MBR
# 22910    3   373  117.495   1236.495     e-Shop
# 22911    5  1043  547.575   5762.575     e-Shop
#
# [9124 rows x 10 columns]

# %%
transactions["tran_date"] = pd.to_datetime(transactions["tran_date"], format='%d-%m-%Y')

# %%
## slash 패턴으로 되어 있었던 데이터 확인
transactions.loc[slash_pattern]
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 144       12323853707   273552 2014-02-12                12              6
# 145       60596009595   274652 2014-02-12                12              5
# 146       17146707816   274897 2014-02-12                12              5
# 147       36792372906   275246 2014-02-12                 2              6
# 148       38821078489   267025 2014-02-12                10              6
# ...               ...      ...        ...               ...            ...
# 22907     80348907828   267124 2011-02-01                 5              3
# 22908     83849473598   269958 2011-02-01                12              5
# 22909     95376486237   269403 2011-02-01                 4              3
# 22910     81365620177   274222 2011-02-01                 3              2
# 22911     85848725285   271131 2011-02-01                 1              4
#
#        Qty  Rate      Tax  total_amt Store_type
# 144      4   510  214.200   2254.200   TeleShop
# 145      4   183   76.860    808.860        MBR
# 146      3   622  195.930   2061.930        MBR
# 147      1  1185  124.425   1309.425     e-Shop
# 148      4   933  391.860   4123.860     e-Shop
# ...    ...   ...      ...        ...        ...
# 22907    2   552  115.920   1219.920   TeleShop
# 22908    3   403  126.945   1335.945     e-Shop
# 22909    5   673  353.325   3718.325        MBR
# 22910    3   373  117.495   1236.495     e-Shop
# 22911    5  1043  547.575   5762.575     e-Shop
#
# [9124 rows x 10 columns]

# %%
## transactions 데이터 타입 확인
transactions.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# dtype: object

# %% [markdown]
# ## **컬럼명 데이터 전처리**

# %% [markdown]
# ### <font color = 'grey'>**컬럼명 소문자로 일괄 변환**</font>

# %%
# transactions 데이터 컬럼명 확인
transactions.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_subcat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt', 'Store_type'],
#       dtype='object')

# %%
# 컬럼명을 소문자로 변경
transactions.columns = transactions.columns.str.lower()
transactions.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_subcat_code',
#        'prod_cat_code', 'qty', 'rate', 'tax', 'total_amt', 'store_type'],
#       dtype='object')

# %%
# customer 데이터 컬럼명 확인
customer.columns
# Out:
# Index(['customer_Id', 'DOB', 'Gender', 'city_code'], dtype='object')

# %%
# 컬럼명을 소문자로 변경
customer.columns = customer.columns.str.lower()
customer.columns
# Out:
# Index(['customer_id', 'dob', 'gender', 'city_code'], dtype='object')

# %%
# prod_cat_info 데이터 컬럼명 확인
prod_cat_info.columns
# Out:
# Index(['prod_cat_code', 'prod_cat', 'prod_sub_cat_code', 'prod_subcat'], dtype='object')

# %% [markdown]
# ### <font color = 'grey'>**컬럼명 통일**</font>

# %%
## customer_id를 cust_id로 변경하기
customer = customer.rename(columns = {'customer_id' : 'cust_id'})
customer.columns
# Out:
# Index(['cust_id', 'dob', 'gender', 'city_code'], dtype='object')

# %%
## transactions의 prod_subcat_code를 prod_sub_cat_code로 변경하기
transactions = transactions.rename(columns = {'prod_subcat_code' : 'prod_sub_cat_code'})
transactions.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_sub_cat_code',
#        'prod_cat_code', 'qty', 'rate', 'tax', 'total_amt', 'store_type'],
#       dtype='object')

# %% [markdown]
# ## **파생 컬럼 생성**
# - Transations 데이터에 **'취소된 거래'와 '최종 주문 거래'를 구분하는 컬럼(confirmed_yn)** 만들기

# %% [markdown]
# ### <font color = 'grey'>**파생 컬럼 생성 전, 거래 내역 구조 파악**</font>

# %%
transactions.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0     80712190438   270351 2014-02-28                  1              1   -5
# 1     29258453508   270384 2014-02-27                  5              3   -5
# 2     51750724947   273420 2014-02-24                  6              5   -2
# 3     93274880719   271509 2014-02-24                 11              6   -3
# 4     51750724947   273420 2014-02-23                  6              5   -2
#
#    rate      tax  total_amt store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
# 샘플 데이터
## 2014년 2월 20일에 주문된 거래 건이 20214년 2월 28일에 취소됨
# 거래 취소된 내역은 qty, rate, total_amt가 음수로 표기가 됨
transactions[transactions['transaction_id'] == 80712190438].sort_values(by='tran_date')
# Out:
#     transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 26     80712190438   270351 2014-02-20                  1              1    5
# 0      80712190438   270351 2014-02-28                  1              1   -5
#
#     rate    tax  total_amt store_type
# 26   772  405.3     4265.3     e-Shop
# 0   -772  405.3    -4265.3     e-Shop

# %% [markdown]
# ### <font color = 'grey'>**주문/취소를 구분하는 order_status 파생 컬럼 만들기**</font>
# - 해당 row가 취소된 거래인지 주문된 거래인지를 구분할 수 있는 파생 컬럼 **order_status**를 만들기
# - 이때 **order_status**는 **total_amt** 값이 음수이면 'Canceled', 양수이면 'Ordered'로 각 범주를 구분

# %%
# order_status 열 추가
transactions['order_status'] = transactions['total_amt'].apply(lambda x: 'Canceled' if x < 0 else 'Ordered')
transactions.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0     80712190438   270351 2014-02-28                  1              1   -5
# 1     29258453508   270384 2014-02-27                  5              3   -5
# 2     51750724947   273420 2014-02-24                  6              5   -2
# 3     93274880719   271509 2014-02-24                 11              6   -3
# 4     51750724947   273420 2014-02-23                  6              5   -2
#
#    rate      tax  total_amt store_type order_status
# 0  -772  405.300  -4265.300     e-Shop     Canceled
# 1 -1497  785.925  -8270.925     e-Shop     Canceled
# 2  -791  166.110  -1748.110   TeleShop     Canceled
# 3 -1363  429.345  -4518.345     e-Shop     Canceled
# 4  -791  166.110  -1748.110   TeleShop     Canceled

# %%
## 샘플 데이터 다시 확인
transactions[transactions['transaction_id'] == 80712190438].sort_values(by='tran_date')
# Out:
#     transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 26     80712190438   270351 2014-02-20                  1              1    5
# 0      80712190438   270351 2014-02-28                  1              1   -5
#
#     rate    tax  total_amt store_type order_status
# 26   772  405.3     4265.3     e-Shop      Ordered
# 0   -772  405.3    -4265.3     e-Shop     Canceled

# %% [markdown]
# - **order_status** 기준으로 각 데이터를 집계
# <ul style = 'list-style-type:square;'>
# <li> <b>전체 주문된 20,876건 중 2,177건이 취소</b>가 된 것을 알 수 있음</li>
# <li>
# 따라서 취소 없이 <b>구매가 확정된 거래 건수는 18,699</b>건으로 파악</li>
# </ul>

# %%
transactions.groupby('order_status').size()
# Out:
# order_status
# Canceled     2177
# Ordered     20876
# dtype: int64

# %%
order_status_count = transactions.groupby('order_status').size()
order_status_count['Ordered'] - order_status_count['Canceled']
# Out:
# 18699

# %% [markdown]
# ### <font color = 'grey'>**구매확정 거래 건을 타나내는 confirmed_yn 파생 컬럼 만들기**</font>

# %% [markdown]
# * <font color = 'brown'> **구매확정 거래 건수만 살펴보기 위한 데이터 전처리**</font>
# <br>
# <ul>
# <li> <b>구매확정 거래 건수 = 총 주문된 거래 건수 - 취소된 거래 건수</b></li>
# <li> order_status 값이 'Caceled'인 경우만 추출하여, canceled_df 테이블 만들기</li>
# <li> canceled_df 테이블은 transaction_id와 confirmed_yn 컬럼으로 구성</li>
# <li> transactions 테이블과 canceled_df 테이블 left join 하기</li>
# <li> transactions 테이블의 confirmed_yn는 0 또는 null 값으로 태깅되어 있음 </li>
# <li> canced_df에서 transaction_id가 있었으면 transactions 테이블의 confirmed_yn은 0, 그렇지 않은면 null </li>
# <li> confirmed_yn 컬럼 값이 결측치인 경우, 1로 대체</li>
#
# </ul>

# %%
# order_status 값이 'Caceled'인 값만 따로 추출하여 canceled_df 테이블 만들기
# canceled_df 생성
canceled_df = (
    transactions
    .loc[transactions['order_status'] == 'Canceled']
    .loc[:, ['transaction_id']]
    .assign(confirmed_yn=0)
    .drop_duplicates()
)
canceled_df.head()
# Out:
#    transaction_id  confirmed_yn
# 0     80712190438             0
# 1     29258453508             0
# 2     51750724947             0
# 3     93274880719             0
# 5     97439039119             0

# %%
# transactions새로운 컬럼인 confirmed_yn에 order_status 값이 'Caceled'인 경우 0으로 표시

# canceled_df 정보 join
transactions = transactions.merge(canceled_df, on='transaction_id', how='left')
transactions.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0     80712190438   270351 2014-02-28                  1              1   -5
# 1     29258453508   270384 2014-02-27                  5              3   -5
# 2     51750724947   273420 2014-02-24                  6              5   -2
# 3     93274880719   271509 2014-02-24                 11              6   -3
# 4     51750724947   273420 2014-02-23                  6              5   -2
#
#    rate      tax  total_amt store_type order_status  confirmed_yn
# 0  -772  405.300  -4265.300     e-Shop     Canceled           0.0
# 1 -1497  785.925  -8270.925     e-Shop     Canceled           0.0
# 2  -791  166.110  -1748.110   TeleShop     Canceled           0.0
# 3 -1363  429.345  -4518.345     e-Shop     Canceled           0.0
# 4  -791  166.110  -1748.110   TeleShop     Canceled           0.0

# %%
## sampling data
transactions[transactions['transaction_id'] == 80712190438].sort_values(by='tran_date')
# Out:
#     transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 26     80712190438   270351 2014-02-20                  1              1    5
# 0      80712190438   270351 2014-02-28                  1              1   -5
#
#     rate    tax  total_amt store_type order_status  confirmed_yn
# 26   772  405.3     4265.3     e-Shop      Ordered           0.0
# 0   -772  405.3    -4265.3     e-Shop     Canceled           0.0

# %%
## confirmed_yn 열을 기준으로 그룹화하고 행의 개수 계산
transactions.groupby('confirmed_yn').size()
# Out:
# confirmed_yn
# 0.0    4234
# dtype: int64

# %%
# confirmed_yn 컬럼 값이 결측치인 경우, 1로 대체
transactions['confirmed_yn'] = transactions['confirmed_yn'].fillna(1)
transactions.head(20)
# Out:
#     transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0      80712190438   270351 2014-02-28                  1              1   -5
# 1      29258453508   270384 2014-02-27                  5              3   -5
# 2      51750724947   273420 2014-02-24                  6              5   -2
# 3      93274880719   271509 2014-02-24                 11              6   -3
# 4      51750724947   273420 2014-02-23                  6              5   -2
# 5      97439039119   272357 2014-02-23                  8              3   -2
# 6      45649838090   273667 2014-02-22                 11              6   -1
# 7      22643667930   271489 2014-02-22                 12              6   -1
# 8      79792372943   275108 2014-02-22                  3              1   -3
# 9      50076728598   269014 2014-02-21                  8              3   -4
# 10     29258453508   270384 2014-02-20                  5              3    5
# 11     25455265351   267750 2014-02-20                 12              6    3
# 12      1571002198   275023 2014-02-20                  6              5    4
# 13     43134751727   268487 2014-02-20                  3              2   -1
# 14     36554696014   269345 2014-02-20                  3              5    3
# 15     56814940239   268799 2014-02-20                  7              5    5
# 16     54295803788   270787 2014-02-20                 12              5    5
# 17     25963520987   274829 2014-02-20                  4              4    3
# 18     17183929085   266863 2014-02-20                  1              2    1
# 19     44783317894   269452 2014-02-20                  3              1    3
#
#     rate      tax  total_amt      store_type order_status  confirmed_yn
# 0   -772  405.300  -4265.300          e-Shop     Canceled           0.0
# 1  -1497  785.925  -8270.925          e-Shop     Canceled           0.0
# 2   -791  166.110  -1748.110        TeleShop     Canceled           0.0
# 3  -1363  429.345  -4518.345          e-Shop     Canceled           0.0
# 4   -791  166.110  -1748.110        TeleShop     Canceled           0.0
# 5   -824  173.040  -1821.040        TeleShop     Canceled           0.0
# 6  -1450  152.250  -1602.250          e-Shop     Canceled           0.0
# 7  -1225  128.625  -1353.625        TeleShop     Canceled           0.0
# 8   -908  286.020  -3010.020             MBR     Canceled           0.0
# 9   -581  244.020  -2568.020          e-Shop     Canceled           0.0
# 10  1497  785.925   8270.925          e-Shop      Ordered           0.0
# 11  1360  428.400   4508.400          e-Shop      Ordered           1.0
# 12   587  246.540   2594.540          e-Shop      Ordered           1.0
# 13  -611   64.155   -675.155          e-Shop     Canceled           0.0
# 14  1253  394.695   4153.695          e-Shop      Ordered           1.0
# 15   368  193.200   2033.200          e-Shop      Ordered           1.0
# 16   584  306.600   3226.600          e-Shop      Ordered           1.0
# 17   502  158.130   1664.130  Flagship store      Ordered           1.0
# 18  1359  142.695   1501.695        TeleShop      Ordered           1.0
# 19   825  259.875   2734.875        TeleShop      Ordered           1.0

# %% [markdown]
# - 앞서 주문 거래 건수에서 취소 거래 건수를 차감한 것이 구매확정 거래 건수라고 했는데, 해당 값인 ***18,699***와 **confirmed_yn** 파생 컬럼으로 구한 구매확정 거래 건수 ***18,819***가 차이가 있는 것을 알 수 있음 => 데이터 이상한 부분 찾기

# %%
## confirmed_yn 열을 기준으로 그룹화하고 행의 개수 다시 계산
transactions.groupby('confirmed_yn').size()
# Out:
# confirmed_yn
# 0.0     4234
# 1.0    18819
# dtype: int64

# %% [markdown]
# ## **이상치 데이터 전처리**

# %% [markdown]
# ### <font color = 'grey'>**데이터 전처리 이후에도 이상치 데이터가 있는지 확인하기**</font>
# - 실습 데이터의 거래 발생 구조상 하나의 transaction_id는 최대 2개의 rows만 가질 수 있음
# <ul>
# <li>주문 후 취소 없이 구매확정된 거래 건 : 1개 레코드</li>
# <li>주문 후 취소가 발생된 거래 건 : 2개 레코드 (주문과 취소)</li>
# </ul>

# %%
# transaction_id가 2개 초과인 데이터 샘플링
summarized_df = transactions.groupby('transaction_id').size().reset_index(name = 'n')
summarized_df[summarized_df['n'] > 2].head()
# Out:
#       transaction_id  n
# 90         426787191  4
# 645       3130889793  3
# 846       4170892941  4
# 944       4545655117  3
# 1135      5479136053  3

# %%
# 샘플 데이터 확인
sample_df = transactions[transactions['transaction_id'] == 426787191].sort_values(by='tran_date')
sample_df
# Out:
#        transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 13168       426787191   273106 2012-05-18                  1              2
# 13156       426787191   273106 2012-05-19                  1              2
# 12961       426787191   273106 2012-05-28                  1              2
# 12967       426787191   273106 2012-05-28                  1              2
#
#        qty  rate     tax  total_amt store_type order_status  confirmed_yn
# 13168    5   109  57.225    602.225     e-Shop      Ordered           0.0
# 13156   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 12961   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 12967   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0

# %% [markdown]
# - 데이터를 보니 2012-05-18에 주문이 발생한 후 2012-05-19에 1건 2012-05-28에 2건의 취소가 있는 것을 알 수 있음
# - 실제 실무에서는 부분 취소로 발생할 수 있는 Case이지만 본 실습에선 이러한 경우를 이상치로 분류하고 데이터 전처리
# - 데이터 전처리 방법은 해당 transaction_id 내 각 주문, 취소 상태(order_status) 안에서 가장 최근에 발생한 거래 데이터만을 남겨둔 채 나머지는 제외
# - 이를 제외하는 방법은 **transaction_id**와 **order_status** 컬럼을 기준으로 partition을 두고 거래 일자가 가장 최신일수록 순번을 매기는 방법. 그 이후 매겨진 순번 중 1번만 남겨둔 채 모두 제외

# %%
## transaction_id, order_status 컬럼을 기준으로 순번 매기기
sample_df = sample_df.sort_values(by=['transaction_id', 'tran_date'], ascending=[True, False])
sample_df['row_num'] = sample_df.groupby(['transaction_id', 'order_status']).cumcount() + 1
sample_df
# Out:
#        transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 12961       426787191   273106 2012-05-28                  1              2
# 12967       426787191   273106 2012-05-28                  1              2
# 13156       426787191   273106 2012-05-19                  1              2
# 13168       426787191   273106 2012-05-18                  1              2
#
#        qty  rate     tax  total_amt store_type order_status  confirmed_yn  \
# 12961   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 12967   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 13156   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 13168    5   109  57.225    602.225     e-Shop      Ordered           0.0
#
#        row_num
# 12961        1
# 12967        2
# 13156        3
# 13168        1

# %%
## 순번이 1번인 것만 남기기
sample_df[sample_df['row_num'] == 1]
# Out:
#        transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 12961       426787191   273106 2012-05-28                  1              2
# 13168       426787191   273106 2012-05-18                  1              2
#
#        qty  rate     tax  total_amt store_type order_status  confirmed_yn  \
# 12961   -5  -109  57.225   -602.225     e-Shop     Canceled           0.0
# 13168    5   109  57.225    602.225     e-Shop      Ordered           0.0
#
#        row_num
# 12961        1
# 13168        1

# %%
## 전체 데이터에 적용 전 transaction_id, tran_date 순으로 정렬
transactions2 = transactions.sort_values(by=['transaction_id', 'tran_date'], ascending=[True, False])
transactions2.head()
# Out:
#        transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 19224         3268991   272172 2011-08-02                 11              6
# 5884          7073244   269640 2013-05-11                 12              5
# 2430         10861359   272671 2013-10-25                  4              4
# 21760        15741026   271544 2011-03-28                 12              5
# 4239         16165359   273203 2013-08-01                  4              1
#
#        qty  rate      tax  total_amt      store_type order_status  \
# 19224    3    91   28.665    301.665          e-Shop      Ordered
# 5884     4  1385  581.700   6121.700             MBR      Ordered
# 2430     2   103   21.630    227.630  Flagship store      Ordered
# 21760    1   299   31.395    330.395          e-Shop      Ordered
# 4239     2   580  121.800   1281.800          e-Shop      Ordered
#
#        confirmed_yn
# 19224           1.0
# 5884            1.0
# 2430            1.0
# 21760           1.0
# 4239            1.0

# %%
## 순번 매기기
transactions2['row_num'] = transactions2.groupby(['transaction_id', 'order_status']).cumcount() + 1
transactions2.head()
# Out:
#        transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 19224         3268991   272172 2011-08-02                 11              6
# 5884          7073244   269640 2013-05-11                 12              5
# 2430         10861359   272671 2013-10-25                  4              4
# 21760        15741026   271544 2011-03-28                 12              5
# 4239         16165359   273203 2013-08-01                  4              1
#
#        qty  rate      tax  total_amt      store_type order_status  \
# 19224    3    91   28.665    301.665          e-Shop      Ordered
# 5884     4  1385  581.700   6121.700             MBR      Ordered
# 2430     2   103   21.630    227.630  Flagship store      Ordered
# 21760    1   299   31.395    330.395          e-Shop      Ordered
# 4239     2   580  121.800   1281.800          e-Shop      Ordered
#
#        confirmed_yn  row_num
# 19224           1.0        1
# 5884            1.0        1
# 2430            1.0        1
# 21760           1.0        1
# 4239            1.0        1

# %%
## 순번이 1인 것만 남기기
transactions2 = transactions2[transactions2['row_num'] == 1]
transactions2.groupby('row_num').size()
# Out:
# row_num
# 1    22935
# dtype: int64

# %% [markdown]
# - transaction_id가 2건 초과인 이상치 전처리 완료
# - 데이터 다시 확인

# %%
# 전처리 방법 1:  전체 주문 건수에서 취소 건수를 차감
order_minus_cancel = transactions2.groupby('order_status').size()
order_minus_cancel
order_minus_cancel['Ordered'] - order_minus_cancel['Canceled']
# Out:
# 18817

# %%
# 전처리 방법 2: confirmed_yn 값을 기준으로 데이터 집계
confirmed_yn_result = transactions2.groupby('confirmed_yn').size()
confirmed_yn_result
# Out:
# confirmed_yn
# 0.0     4116
# 1.0    18819
# dtype: int64

# %% [markdown]
# - 전처리 방법 1의 결과와 전처리 방법 2의 결과가 같지 않음
# - 추가적인 데이터 전처리 필요 => **Ordered 주문건은 없고, Canceld 주문 건이 있는지 확인**

# %%
# 전처리 방법 1의 결과와 전처리 방법 2의 결과가 같지 않음
# 추가적인 데이터 전처리 필요
# Ordered 주문건은 없고, Canceld 주문 건이 있는지 확인
order_minus_cancel['Ordered'] - order_minus_cancel['Canceled'] == confirmed_yn_result[1.0]
# Out:
# False

# %% [markdown]
# ### <font color = 'grey'>**주문은 없고, 취소가 발생한 건이 있는지 확인**</font>

# %%
# transaction_id 단위로 각 주문 상태별 레코드 집계
od_ca_result = transactions2.groupby('transaction_id').agg(
    od_n=pd.NamedAgg(column='order_status', aggfunc=lambda x: (x == 'Ordered').sum()),
    ca_n=pd.NamedAgg(column='order_status', aggfunc=lambda x: (x == 'Canceled').sum())
).reset_index()
od_ca_result.head()
# Out:
#    transaction_id  od_n  ca_n
# 0         3268991     1     0
# 1         7073244     1     0
# 2        10861359     1     0
# 3        15741026     1     0
# 4        16165359     1     0

# %%
# 'od_n'이 0인 행만 필터링(주문은 없고 취소만 있는 Case) 후 omit_df 객체로 assign
omit_df = od_ca_result[od_ca_result['od_n'] == 0]
omit_df
# Out:
#        transaction_id  od_n  ca_n
# 1851       8868056339     0     1
# 20329     97439039119     0     1

# %%
# sampling data
transactions2[transactions2['transaction_id'] == 8868056339].sort_values(by='tran_date')
# Out:
#     transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 70      8868056339   268145 2014-02-17                  2              6   -2
#
#     rate    tax  total_amt store_type order_status  confirmed_yn  row_num
# 70  -152  31.92    -335.92     e-Shop     Canceled           0.0        1

# %% [markdown]
# - 주문 건은 없고 취소 건만 있는 2개의 transaction_id를 찾음
# - 이제 이 2개의 이상치 데이터를 제외하고, 다시 transactions 객체를 assign

# %%
## 이상치 제외하기
transactions3 = transactions2[~transactions2['transaction_id'].isin(omit_df['transaction_id'])]
transactions3 = transactions3.reset_index(drop=True)
transactions3.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0         3268991   272172 2011-08-02                 11              6    3
# 1         7073244   269640 2013-05-11                 12              5    4
# 2        10861359   272671 2013-10-25                  4              4    2
# 3        15741026   271544 2011-03-28                 12              5    1
# 4        16165359   273203 2013-08-01                  4              1    2
#
#    rate      tax  total_amt      store_type order_status  confirmed_yn  \
# 0    91   28.665    301.665          e-Shop      Ordered           1.0
# 1  1385  581.700   6121.700             MBR      Ordered           1.0
# 2   103   21.630    227.630  Flagship store      Ordered           1.0
# 3   299   31.395    330.395          e-Shop      Ordered           1.0
# 4   580  121.800   1281.800          e-Shop      Ordered           1.0
#
#    row_num
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
## 최종 검증
order_minus_cancel = transactions3.groupby('order_status').size()
order_minus_cancel
# Out:
# order_status
# Canceled     2057
# Ordered     20876
# dtype: int64

# %%
order_minus_cancel['Ordered'] - order_minus_cancel['Canceled']
# Out:
# 18819

# %%
# confirmed_yn 값으 기준으로 데이터 집계
confirmed_yn_result = transactions3.groupby('confirmed_yn').size()
confirmed_yn_result
# Out:
# confirmed_yn
# 0.0     4114
# 1.0    18819
# dtype: int64

# %%
order_minus_cancel['Ordered'] - order_minus_cancel['Canceled'] == confirmed_yn_result[1.0]
# Out:
# True

# %% [markdown]
# ## **데이터 결합 전처리**

# %% [markdown]
# - **Customer**, **Transactions**, **prod_cat_info** 데이터에 분석에 필요한 정보를 하나의 객체로 결합

# %% [markdown]
# ### <font color = 'grey'>**Customer 데이터 정보 결합**</font>
# - Customer 데이터와 Transactions 데이터의 공통 Key 값인 **cust_id**를 기준으로 테이블 결합

# %%
# transactions3를 transactions로 다시 Assign 후 필요없는 row_num 컬럼은 제외
transactions = transactions3.drop(columns = ['row_num'])
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22933 entries, 0 to 22932
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     22933 non-null  int64
#  1   cust_id            22933 non-null  int64
#  2   tran_date          22933 non-null  datetime64[ns]
#  3   prod_sub_cat_code  22933 non-null  int64
#  4   prod_cat_code      22933 non-null  int64
#  5   qty                22933 non-null  int64
#  6   rate               22933 non-null  int64
#  7   tax                22933 non-null  float64
#  8   total_amt          22933 non-null  float64
#  9   store_type         22933 non-null  object
#  10  order_status       22933 non-null  object
#  11  confirmed_yn       22933 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(2)
# memory usage: 2.1+ MB

# %%
# customer 데이터 프레임 결합
merge_trans_cust = transactions.merge(customer, on='cust_id', how='left')
merge_trans_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22933 entries, 0 to 22932
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     22933 non-null  int64
#  1   cust_id            22933 non-null  int64
#  2   tran_date          22933 non-null  datetime64[ns]
#  3   prod_sub_cat_code  22933 non-null  int64
#  4   prod_cat_code      22933 non-null  int64
#  5   qty                22933 non-null  int64
#  6   rate               22933 non-null  int64
#  7   tax                22933 non-null  float64
#  8   total_amt          22933 non-null  float64
#  9   store_type         22933 non-null  object
#  10  order_status       22933 non-null  object
#  11  confirmed_yn       22933 non-null  float64
#  12  dob                22933 non-null  datetime64[ns]
#  13  gender             22933 non-null  object
#  14  city_code          22933 non-null  float64
# dtypes: datetime64[ns](2), float64(4), int64(6), object(3)
# memory usage: 2.6+ MB

# %%
## 결측치 확인
merge_trans_cust.isnull().sum()
# Out:
# transaction_id       0
# cust_id              0
# tran_date            0
# prod_sub_cat_code    0
# prod_cat_code        0
# qty                  0
# rate                 0
# tax                  0
# total_amt            0
# store_type           0
# order_status         0
# confirmed_yn         0
# dob                  0
# gender               0
# city_code            0
# dtype: int64

# %% [markdown]
# - dbo 컬럼 활용하여 연령 구하기 위한 파생 컬럼 생성
# <ul><li>연 나이 = 거래 연도 - 생일 연도</li>

# %%
## age 파생 컬럼 생성을 위해 각 tran_date, dob 데이터에서 연도만 추출
merge_trans_cust['tran_date_year'] = merge_trans_cust['tran_date'].dt.year
merge_trans_cust['dob_year'] = merge_trans_cust['dob'].dt.year
merge_trans_cust.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0         3268991   272172 2011-08-02                 11              6    3
# 1         7073244   269640 2013-05-11                 12              5    4
# 2        10861359   272671 2013-10-25                  4              4    2
# 3        15741026   271544 2011-03-28                 12              5    1
# 4        16165359   273203 2013-08-01                  4              1    2
#
#    rate      tax  total_amt      store_type order_status  confirmed_yn  \
# 0    91   28.665    301.665          e-Shop      Ordered           1.0
# 1  1385  581.700   6121.700             MBR      Ordered           1.0
# 2   103   21.630    227.630  Flagship store      Ordered           1.0
# 3   299   31.395    330.395          e-Shop      Ordered           1.0
# 4   580  121.800   1281.800          e-Shop      Ordered           1.0
#
#          dob gender  city_code  tran_date_year  dob_year
# 0 1975-09-17      M       10.0            2011      1975
# 1 1970-04-29      M        7.0            2013      1970
# 2 1974-04-01      F        7.0            2013      1974
# 3 1986-05-08      F        5.0            2011      1986
# 4 1984-02-29      M        2.0            2013      1984

# %%
## 추출한 각 연도 값의 차이를 통해 age 컬럼 생성
merge_trans_cust['age'] = merge_trans_cust['tran_date_year'] - merge_trans_cust['dob_year']

# 'tran_date_year'와 'dob_year' 열은 이제 더 이상 필요하지 않으므로 삭제
merge_trans_cust = merge_trans_cust.drop(['tran_date_year', 'dob_year'], axis=1)

# %% [markdown]
# ### <font color = 'grey'>**prod_cat_info 데이터 정보 결합**</font>

# %% [markdown]
# - 앞서 데이터를 결합한 **merge_trans_cust** 객체에 **prod_cat_info**의 카테고리 명칭을 결합<br>

# %%
## prod_cat_info 테이블 정보
prod_cat_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   prod_cat_code      23 non-null     int64
#  1   prod_cat           23 non-null     object
#  2   prod_sub_cat_code  23 non-null     int64
#  3   prod_subcat        23 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 864.0+ bytes

# %%
prod_cat_info.iloc[:5]
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %% [markdown]
# - **prod_cat_info** 테이블과 **transactions** 테이블에 **prod_cat_code**와 **prod_sub_cat_code** 두 개의 컬럼이 존재
#
# - 이 두 컬럼을 기준으로 데이터를 결합

# %%
## prod_cat_code, prod_sub_cat_code 기준으로 데이터 결합
merge_trans_cust_prod = pd.merge(merge_trans_cust, prod_cat_info, on=['prod_cat_code', 'prod_sub_cat_code'], how='left')
merge_trans_cust_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22933 entries, 0 to 22932
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     22933 non-null  int64
#  1   cust_id            22933 non-null  int64
#  2   tran_date          22933 non-null  datetime64[ns]
#  3   prod_sub_cat_code  22933 non-null  int64
#  4   prod_cat_code      22933 non-null  int64
#  5   qty                22933 non-null  int64
#  6   rate               22933 non-null  int64
#  7   tax                22933 non-null  float64
#  8   total_amt          22933 non-null  float64
#  9   store_type         22933 non-null  object
#  10  order_status       22933 non-null  object
#  11  confirmed_yn       22933 non-null  float64
#  12  dob                22933 non-null  datetime64[ns]
#  13  gender             22933 non-null  object
#  14  city_code          22933 non-null  float64
#  15  age                22933 non-null  int32
#  16  prod_cat           22933 non-null  object
#  17  prod_subcat        22933 non-null  object
# dtypes: datetime64[ns](2), float64(4), int32(1), int64(6), object(5)
# memory usage: 3.1+ MB

# %%
## 결측치 확인
merge_trans_cust_prod.isnull().sum()
# Out:
# transaction_id       0
# cust_id              0
# tran_date            0
# prod_sub_cat_code    0
# prod_cat_code        0
# qty                  0
# rate                 0
# tax                  0
# total_amt            0
# store_type           0
# order_status         0
# confirmed_yn         0
# dob                  0
# gender               0
# city_code            0
# age                  0
# prod_cat             0
# prod_subcat          0
# dtype: int64

# %%
merge_trans_cust_prod.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_sub_cat_code  prod_cat_code  qty  \
# 0         3268991   272172 2011-08-02                 11              6    3
# 1         7073244   269640 2013-05-11                 12              5    4
# 2        10861359   272671 2013-10-25                  4              4    2
# 3        15741026   271544 2011-03-28                 12              5    1
# 4        16165359   273203 2013-08-01                  4              1    2
#
#    rate      tax  total_amt      store_type order_status  confirmed_yn  \
# 0    91   28.665    301.665          e-Shop      Ordered           1.0
# 1  1385  581.700   6121.700             MBR      Ordered           1.0
# 2   103   21.630    227.630  Flagship store      Ordered           1.0
# 3   299   31.395    330.395          e-Shop      Ordered           1.0
# 4   580  121.800   1281.800          e-Shop      Ordered           1.0
#
#          dob gender  city_code  age          prod_cat prod_subcat
# 0 1975-09-17      M       10.0   36  Home and kitchen        Bath
# 1 1970-04-29      M        7.0   43             Books    Academic
# 2 1974-04-01      F        7.0   39              Bags       Women
# 3 1986-05-08      F        5.0   25             Books    Academic
# 4 1984-02-29      M        2.0   29          Clothing        Mens

# %%
## 카테고리 명칭 정보가 제대로 결합되었는지 샘플링하여 점검
prod_cat_info[(prod_cat_info['prod_sub_cat_code'] == 11) & (prod_cat_info['prod_cat_code'] == 6)]
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code prod_subcat
# 21              6  Home and kitchen                 11        Bath

# %% [markdown]
# ## **전처리 데이터 컬럼 위치 조정 및 분석을 위한 데이터 저장**

# %% [markdown]
# ### <font color = 'grey'>**컬럼명 위치 조정**</font>

# %%
# 컬럼명 위치 조정
desired_order = [
    'cust_id', 'dob', 'age', 'gender', 'city_code', 'order_status', 'confirmed_yn',
    'transaction_id', 'tran_date', 'prod_cat_code', 'prod_sub_cat_code', 'prod_cat',
    'prod_subcat', 'qty', 'rate', 'tax', 'total_amt', 'store_type'
]
merge_trans_cust_prod = merge_trans_cust_prod.reindex(columns=desired_order)
merge_trans_cust_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22933 entries, 0 to 22932
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cust_id            22933 non-null  int64
#  1   dob                22933 non-null  datetime64[ns]
#  2   age                22933 non-null  int32
#  3   gender             22933 non-null  object
#  4   city_code          22933 non-null  float64
#  5   order_status       22933 non-null  object
#  6   confirmed_yn       22933 non-null  float64
#  7   transaction_id     22933 non-null  int64
#  8   tran_date          22933 non-null  datetime64[ns]
#  9   prod_cat_code      22933 non-null  int64
#  10  prod_sub_cat_code  22933 non-null  int64
#  11  prod_cat           22933 non-null  object
#  12  prod_subcat        22933 non-null  object
#  13  qty                22933 non-null  int64
#  14  rate               22933 non-null  int64
#  15  tax                22933 non-null  float64
#  16  total_amt          22933 non-null  float64
#  17  store_type         22933 non-null  object
# dtypes: datetime64[ns](2), float64(4), int32(1), int64(6), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# ### <font color = 'grey'>**분석용 데이터 저장**</font>

# %%
# merge_trans_cust_prod 데이터프레임을 CSV 파일로 저장
merge_trans_cust_prod.to_csv('/content/drive/MyDrive/DataDreamworks/패스트캠퍼스/커머스/class01/data/merge_trans_cust_prod_240327.csv', index=False)
